# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("ionosphere.data.csv")
data.head()
# Out:
#    A  B        C        D        E        F        G        H        I  \
# 0  1  0  0.99539 -0.05889  0.85243  0.02306  0.83398 -0.37708  1.00000
# 1  1  0  1.00000 -0.18829  0.93035 -0.36156 -0.10868 -0.93597  1.00000
# 2  1  0  1.00000 -0.03365  1.00000  0.00485  1.00000 -0.12062  0.88965
# 3  1  0  1.00000 -0.45161  1.00000  1.00000  0.71216 -1.00000  0.00000
# 4  1  0  1.00000 -0.02401  0.94140  0.06531  0.92106 -0.23255  0.77152
#
#          J  ...        Z       AA       AB       AC       AD       AE  \
# 0  0.03760  ... -0.51171  0.41078 -0.46168  0.21266 -0.34090  0.42267
# 1 -0.04549  ... -0.26569 -0.20468 -0.18401 -0.19040 -0.11593 -0.16626
# 2  0.01198  ... -0.40220  0.58984 -0.22145  0.43100 -0.17365  0.60436
# 3  0.00000  ...  0.90695  0.51613  1.00000  1.00000 -0.20099  0.25682
# 4 -0.16399  ... -0.65158  0.13290 -0.53206  0.02431 -0.62197 -0.05707
#
#         AF       AG       AH  Class
# 0 -0.54487  0.18641 -0.45300      g
# 1 -0.06288 -0.13738 -0.02447      b
# ...

# %%
X = data.drop('Class', axis="columns")
X.head()
# Out:
#    A  B        C        D        E        F        G        H        I  \
# 0  1  0  0.99539 -0.05889  0.85243  0.02306  0.83398 -0.37708  1.00000
# 1  1  0  1.00000 -0.18829  0.93035 -0.36156 -0.10868 -0.93597  1.00000
# 2  1  0  1.00000 -0.03365  1.00000  0.00485  1.00000 -0.12062  0.88965
# 3  1  0  1.00000 -0.45161  1.00000  1.00000  0.71216 -1.00000  0.00000
# 4  1  0  1.00000 -0.02401  0.94140  0.06531  0.92106 -0.23255  0.77152
#
#          J  ...        Y        Z       AA       AB       AC       AD  \
# 0  0.03760  ...  0.56811 -0.51171  0.41078 -0.46168  0.21266 -0.34090
# 1 -0.04549  ... -0.20332 -0.26569 -0.20468 -0.18401 -0.19040 -0.11593
# 2  0.01198  ...  0.57528 -0.40220  0.58984 -0.22145  0.43100 -0.17365
# 3  0.00000  ...  1.00000  0.90695  0.51613  1.00000  1.00000 -0.20099
# 4 -0.16399  ...  0.03286 -0.65158  0.13290 -0.53206  0.02431 -0.62197
#
#         AE       AF       AG       AH
# 0  0.42267 -0.54487  0.18641 -0.45300
# 1 -0.16626 -0.06288 -0.13738 -0.02447
# ...

# %%
y = data['Class']
y
# Out:
# 0      g
# 1      b
# 2      g
# 3      b
# 4      g
#       ..
# 346    g
# 347    g
# 348    g
# 349    g
# 350    g
# Name: Class, Length: 351, dtype: object

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=42)

# %%
X_train
# Out:
#      A  B        C        D        E        F        G        H        I  \
# 78   1  0  1.00000  0.24168  1.00000  0.48590  1.00000  0.72973  1.00000
# 90   1  0  0.88305 -0.21996  1.00000  0.36373  0.82403  0.19206  0.85086
# 16   1  0  0.99645  0.06468  1.00000 -0.01236  0.97811  0.02498  0.96112
# 66   1  0  1.00000  0.28046  1.00000  0.02477  1.00000  0.07764  1.00000
# 288  1  0  0.87111  0.04326  0.79946  0.18297  0.99009  0.29292  0.89455
# ..  .. ..      ...      ...      ...      ...      ...      ...      ...
# 71   0  0  1.00000 -1.00000  1.00000  1.00000 -1.00000 -1.00000  1.00000
# 106  1  0  0.00000  0.00000  0.00000  0.00000  0.00000  0.00000  0.00000
# 270  1  0  1.00000  0.08013  0.96775 -0.00482  0.96683 -0.00722  0.87980
# 348  1  0  0.94701 -0.00034  0.93207 -0.03227  0.95177 -0.03431  0.95584
# 102  0  0  0.00000  0.00000  0.00000  0.00000  0.00000  0.00000  0.00000
#
#            J  ...        Y        Z       AA       AB       AC       AD  \
# ...

# %%
X_test
# Out:
#      A  B        C        D        E        F        G        H        I  \
# 157  1  0  0.47090  0.22751  0.42328  0.33598  0.25661  0.47619  0.01852
# 342  1  0  0.82254 -0.07572  0.80462  0.00231  0.87514 -0.01214  0.86821
# 316  1  0  0.89589  0.39286  0.66129  0.71804  0.29521  0.90824 -0.04787
# 234  1  0  0.68729  1.00000  0.91973 -0.76087  0.81773  0.04348  0.76087
# 155  1  0  0.72414 -0.01084  0.79704  0.01084  0.80000  0.00197  0.79015
# ..  .. ..      ...      ...      ...      ...      ...      ...      ...
# 181  1  0  1.00000  0.24077  0.99815  0.00369  0.80244 -0.30133  0.89919
# 179  1  0  1.00000 -0.08183  1.00000 -0.11326  0.99246 -0.29802  1.00000
# 199  1  0  0.79847  0.38265  0.80804 -0.16964  1.00000 -0.07653  0.98151
# 327  1  0  1.00000  1.00000  0.36700  0.06158  0.12993  0.92713 -0.27586
# 228  0  0  1.00000 -1.00000  1.00000  1.00000  1.00000  1.00000  1.00000
#
#            J  ...        Y        Z       AA       AB       AC       AD  \
# ...

# %%
model = RandomForestRegressor(random_state=42)
model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
# Create PDP for 'sepal_length'
feature_name = 'F'
feature_values = sorted(X_train[feature_name].unique())  # Use unique values of 'sepal_length'
print(feature_values)
# Out:
# [-1.0, -0.80553, -0.78509, -0.36156, -0.33203, -0.2963, -0.25346, -0.2381, -0.22703, -0.208, -0.20253, -0.18388, -0.18343, -0.17674, -0.17263, -0.14706, -0.14545, -0.1438, -0.14333, -0.13936, -0.13244, -0.13009, -0.1269, -0.12371, -0.12144, -0.11313, -0.11057, -0.10566, -0.10417, -0.10345, -0.10169, -0.09834, -0.0961, -0.08493, -0.08156, -0.06935, -0.06151, -0.05676, -0.05667, -0.05558, -0.05357, -0.04119, -0.04104, -0.03818, -0.03692, -0.03227, -0.03142, -0.02744, -0.02723, -0.02703, -0.02465, -0.02439, -0.02423, -0.02299, -0.01989, -0.01918, -0.01773, -0.01272, -0.01236, -0.01209, -0.00846, -0.00482, -0.00343, -0.0026, -0.00228, -0.00143, 0.0, 0.00202, 0.00258, 0.00343, 0.00481, 0.00485, 0.00843, 0.01001, 0.01038, 0.01105, 0.0127, 0.01305, 0.01348, 0.01456, 0.01566, 0.01659, 0.01756, 0.0178, 0.01954, 0.0228, 0.02306, 0.02477, 0.02543, 0.02919, 0.02942, 0.03131, 0.03309, 0.0342, 0.03457, 0.03462, 0.04068, 0.04328, 0.04348, 0.04598, 0.04918, 0.05031, 0.05545, 0.05825, 0.06531, 0.0666
# ...

# %%
# Make a copy of the dataset to modify only the 'sepal_length' column
X_temp = X_train.copy()

# %%
pdp_values = []

# %%
# Iterate over unique values of 'sepal_length'
for value in feature_values:
    X_temp[feature_name] = value  # Set 'sepal_length' to the current value for all samples
    print(X_temp)
    prediction = model.predict(X_temp)  # Predict using the modified dataset
    pdp_values.append(np.mean(prediction))  # Store the average prediction
# Out:
#      A  B        C        D        E    F        G        H        I        J  \
# 78   1  0  1.00000  0.24168  1.00000 -1.0  1.00000  0.72973  1.00000  1.00000
# 90   1  0  0.88305 -0.21996  1.00000 -1.0  0.82403  0.19206  0.85086  0.05901
# 16   1  0  0.99645  0.06468  1.00000 -1.0  0.97811  0.02498  0.96112  0.02312
# 66   1  0  1.00000  0.28046  1.00000 -1.0  1.00000  0.07764  1.00000  0.04317
# 288  1  0  0.87111  0.04326  0.79946 -1.0  0.99009  0.29292  0.89455 -0.08337
# ..  .. ..      ...      ...      ...  ...      ...      ...      ...      ...
# 71   0  0  1.00000 -1.00000  1.00000 -1.0 -1.00000 -1.00000  1.00000 -1.00000
# 106  1  0  0.00000  0.00000  0.00000 -1.0  0.00000  0.00000  0.00000  0.00000
# 270  1  0  1.00000  0.08013  0.96775 -1.0  0.96683 -0.00722  0.87980 -0.03923
# 348  1  0  0.94701 -0.00034  0.93207 -1.0  0.95177 -0.03431  0.95584  0.02446
# 102  0  0  0.00000  0.00000  0.00000 -1.0  0.00000  0.00000  0.00000  0.00000
#
# ...

# %%
# Plotting the Partial Dependence Plot
plt.figure(figsize=(8, 6))
plt.plot(C_values, pdp_values)
plt.xlabel(feature_name)
plt.ylabel('Average Prediction')
plt.title('Partial Dependence Plot for F')
plt.grid(True)
plt.show()
